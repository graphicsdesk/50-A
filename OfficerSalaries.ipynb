# %% [markdown]
# # Payroll Records of Substantiated Cops
# #### The payroll records of NYPD officers with substantiated complaints
# #### The top table has average values calculated from 2014 to 2019
# #### Individual tables for each officer (separated by every fiscal year) will follow
# ### Definitions(?):
# baseSalary (in dollars) - The "base salary" assigned to the officer<br>
# regHours - Number of hours worked by the officer<br>
# regGrossPay (in dollars) - Actual amount of money received by officer as their "base salary" (May differ from assigned base salary)<br>
# overtimeHours - Number of overtime hours worked by the officer<br>
# overtimePay (in dollars) - Amount received by the officer as payment for working overtime<br>
# otherPay (in dollars) - Amount received by the officer that cannot be classified under their base salary or overtime pay<br>
# %changeBaseSalary - Percent Change in base salary compared to the previous year

# %% [markdown]
# ## Overall Table (Averages)

# %%
display(copSalaries2)
# Out:
#          Last Name     First Name  averageBaseSalary  averageRegularHours  \
# 0             HAMM         YUSEFF       70462.470588          2052.294118
# 1        CREIGHTON         KIERAN      123999.263158          2072.526316
# 2        CARBONELL        ROLANDO       72251.882353          2071.647059
# 3    RODRIGUEZ JR.        WILBERT       78171.315789          2072.526316
# 4    ITURRALDE JR.         RAFAEL       72462.000000          2076.000000
# 5        SCOLOVENO        MICHAEL       76267.750000          2075.750000
# 6            VELEZ          MARCY       66509.315789          2004.263158
# 7          CATTANI         ROBERT       74626.909091          2076.454545
# 8          MORALES         RONNIE       64751.083333          1989.083333
# 9            FELIZ      WELINGTON       99147.315789          2072.526316
# 10        GOTTLIEB       BENJAMIN       78905.157895          2072.526316
# 11          STOKES          BARRY       58822.909091          1889.636364
# ...

# %% [markdown]
# ## Yuseff Hamm
# #### 2 exonerated charges in 2002<br><br>1 exonerated charge in 2004

# %%
display(hamm)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2002     34,514  1,994 hrs      29,933       409 hrs       5,390    1,996
# 1   2003     40,617  2,080 hrs      41,172       366 hrs       6,717    5,492
# 2   2004     44,145  2,080 hrs      39,764       526 hrs      10,321    5,711
# 3   2005     48,321  2,080 hrs      41,722       580 hrs      12,343    5,207
# 4   2006     52,148  2,086 hrs      58,919       416 hrs      18,992    6,437
# 5   2007     67,997  1,854 hrs      54,378        45 hrs       2,389   10,690
# 6   2008     70,717  2,091 hrs      59,265         0 hrs           0   11,692
# 7   2009     73,546  2,086 hrs      97,474         0 hrs       2,212   16,230
# 8   2010     76,488  2,086 hrs      81,350        94 hrs       3,655   12,875
# 9   2011     76,488  2,086 hrs      76,279       273 hrs      18,329   10,090
# 10  2012     76,488  1,920 hrs      69,807       346 hrs      21,665   12,074
# ...

# %% [markdown]
# ## Kieran Creighton
# #### 2 substantiated charges in 2003, 3 charges overall

# %%
display(creighton)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2000     57,843  1,920 hrs      51,862        60 hrs       2,013    8,779
# 1   2001     68,425  2,080 hrs      61,608       174 hrs       4,429   10,726
# 2   2002     72,027  2,080 hrs      71,760       651 hrs      23,768   13,252
# 3   2003     77,392  2,080 hrs      72,524       273 hrs       9,390   15,398
# 4   2004     87,700  2,080 hrs      76,105       367 hrs      14,430   16,375
# 5   2005     92,508  2,080 hrs      82,019       201 hrs       6,940   15,359
# 6   2006     97,126  2,086 hrs      87,959         0 hrs           0   15,581
# 7   2007    103,440  2,086 hrs      93,950         0 hrs       1,348   13,724
# 8   2008    130,312  2,091 hrs     144,812         0 hrs           0   20,745
# 9   2009    135,524  2,086 hrs     133,560         0 hrs           0   16,827
# 10  2010    140,945  2,086 hrs     136,341         0 hrs           0   17,932
# ...

# %% [markdown]
# ## Rolando Carbonell
# #### 2 charges, 1 disciplined in 2004 ; 2 more exonerated charges in 2004

# %%
display(carbonell)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2000     36,681  1,920 hrs      32,397       116 hrs       2,052    4,467
# 1   2001     39,955  2,080 hrs      36,814       129 hrs       2,282    5,380
# 2   2002     54,048  2,080 hrs      39,811       605 hrs      10,504    5,989
# 3   2003     56,750  2,080 hrs      59,355       280 hrs       9,705   11,715
# 4   2004     59,588  2,080 hrs      53,759       359 hrs      10,678   11,579
# 5   2005     62,269  2,080 hrs      53,893       402 hrs      11,964   11,599
# 6   2006     65,382  2,086 hrs      74,734        57 hrs       5,672   13,806
# 7   2007     70,909  2,086 hrs      59,425        61 hrs       3,158   12,039
# 8   2008     73,913  2,091 hrs      67,424        74 hrs       3,819    9,475
# 9   2009     74,100  2,086 hrs      89,097        35 hrs       3,651   19,313
# 10  2010     78,198  2,086 hrs      80,399         8 hrs         703   16,235
# ...

# %% [markdown]
# ## Wilbert Rodriguez Jr.
# #### 4 exonerated charges in 2004

# %%
display(rodriguez)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2002     34,514  1,920 hrs      29,161       371 hrs       4,717    1,956
# 1   2003     40,617  2,080 hrs      41,079       341 hrs       6,818    3,426
# 2   2004     44,145  2,080 hrs      39,730       598 hrs      11,665    3,249
# 3   2005     48,321  2,080 hrs      41,675       656 hrs      12,821    5,075
# 4   2006     52,148  2,086 hrs      58,776       452 hrs      18,768    4,290
# 5   2007     64,225  2,086 hrs      59,379       741 hrs      34,934    6,211
# 6   2008     69,182  2,091 hrs      64,453       556 hrs      27,797    8,717
# 7   2009     77,480  2,086 hrs      86,991       457 hrs      31,779     -854
# 8   2010     81,120  2,086 hrs      78,282       649 hrs      40,764    8,955
# 9   2011     87,278  2,086 hrs      83,397       610 hrs      39,322   12,016
# 10  2012     87,278  2,091 hrs      86,809       589 hrs      40,847   12,135
# ...

# %% [markdown]
# ## Rafael Iturralde Jr.
# #### 2 unsubstantiated, 1 exonerated, and 1 disciplined charge(s) in 2004

# %%
display(iturralde)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2002     34,514  1,994 hrs      29,933       304 hrs       5,493    1,996
# 1   2003     40,617  2,080 hrs      41,172       320 hrs       5,927    4,419
# 2   2004     44,145  2,080 hrs      39,764       462 hrs       8,824    3,249
# 3   2005     48,321  2,080 hrs      41,722       694 hrs      13,545    5,248
# 4   2006     52,148  2,086 hrs      58,814       373 hrs      16,583    4,598
# 5   2007     67,997  2,086 hrs      59,193       665 hrs      30,130    8,822
# 6   2008     68,982  2,091 hrs      62,920       660 hrs      31,155    9,216
# 7   2009     77,480  2,086 hrs      91,207       711 hrs      48,541   12,026
# 8   2010     81,120  2,086 hrs      78,282       699 hrs      42,267   11,801
# 9   2011     87,278  2,086 hrs      83,397       616 hrs      39,396   11,645
# 10  2012     87,278  2,091 hrs      86,809       491 hrs      34,369   17,753
# ...

# %% [markdown]
# ## Michael Scoloveno
# #### 6 exonerated, 1 disciplined charge(s) in 2006

# %%
display(scoloveno)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2003     38,722  1,994 hrs      35,067        81 hrs       1,235    2,968
# 1   2004     42,648  2,080 hrs      38,397       573 hrs       9,039    5,546
# 2   2005     46,132  2,080 hrs      39,859       906 hrs      14,837    5,751
# 3   2006     50,737  2,086 hrs      57,148       430 hrs      18,893    7,624
# 4   2007     54,234  2,086 hrs      47,375       523 hrs      17,590    6,720
# 5   2008     70,717  2,091 hrs      59,034       582 hrs      29,530   10,943
# 6   2009     77,480  2,086 hrs      96,296       510 hrs      38,218   16,076
# 7   2010     81,120  2,086 hrs      75,948       460 hrs      28,036   12,105
# 8   2011     83,802  2,086 hrs      78,624       569 hrs      37,572   12,783
# 9   2012     87,278  2,091 hrs      95,567       593 hrs      40,400    6,868
# 10  2013     87,278  2,086 hrs      83,735       323 hrs      23,959   12,841
# ...

# %% [markdown]
# ## Marcy Velez
# #### 3 exonerated, 1 unsubstantiated charge(s) in 2008<br><br>2 unsubstantiated charges in 2010

# %%
display(velez)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2000     31,305    623 hrs       9,323         0 hrs           0        0
# 1   2001     34,980  2,080 hrs      31,811        28 hrs         461    2,125
# 2   2002     38,541  2,080 hrs      33,705       736 hrs      13,042    5,036
# 3   2003     44,038  2,080 hrs      44,939       374 hrs       8,430    5,998
# 4   2004     47,526  2,080 hrs      42,048       449 hrs       8,178    5,822
# 5   2005     62,269  2,080 hrs      46,071       462 hrs      10,817    6,373
# 6   2006     65,382  2,086 hrs      72,231       317 hrs      18,113   13,375
# 7   2007     67,997  2,086 hrs      59,425       425 hrs      20,097   12,015
# 8   2008     70,717  2,091 hrs      59,265       350 hrs      17,425   11,856
# 9   2009     73,546  2,086 hrs      99,509       361 hrs      27,962   18,426
# 10  2010     76,488  2,086 hrs      75,993       401 hrs      25,505   14,538
# ...

# %% [markdown]
# ## Robert Cattani
# #### 1 substantiated/charged charge in 2009

# %%
display(cattani)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2008     38,809  2,046 hrs      27,360        81 hrs       1,749    2,378
# 1   2009     41,965  2,086 hrs      50,346       196 hrs       5,919    4,795
# 2   2010     48,779  2,086 hrs      45,615       199 hrs       6,787    7,312
# 3   2011     53,270  2,086 hrs      50,626       352 hrs      13,333    4,869
# 4   2012     56,609  2,091 hrs      54,443       354 hrs      14,663    2,618
# 5   2013     76,488  2,086 hrs      65,053       573 hrs      28,640   10,629
# 6   2014     83,802  2,086 hrs      80,206       420 hrs      27,703   11,706
# 7   2015    102,054  2,086 hrs      98,470       331 hrs      25,661   15,812
# 8   2016    103,585  2,091 hrs     105,442       446 hrs      37,013   15,255
# 9   2017    106,175  2,051 hrs     109,091       426 hrs      37,071   12,554
# 10  2018    109,360  2,046 hrs     106,635       379 hrs      32,053   14,235

# %% [markdown]
# ## Ronnie Morales
# #### 4 substantiated charges in 2009<br><br>1 unsubstantiated charge in 2010

# %%
display(morales)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2007     37,316    983 hrs      11,347        55 hrs         992        0
# 1   2008     38,809  2,091 hrs      33,378       133 hrs       3,284    3,944
# 2   2009     41,965  2,086 hrs      52,091       264 hrs       8,451    5,701
# 3   2010     48,779  2,086 hrs      48,178       136 hrs       5,802    7,336
# 4   2011     53,270  2,086 hrs      52,878       169 hrs       6,020    7,835
# 5   2012     56,609  2,091 hrs      56,113       271 hrs      11,678    9,302
# 6   2013     76,488  2,086 hrs      75,020       318 hrs      18,654   15,854
# 7   2014     76,488  2,086 hrs      76,279       236 hrs      16,074   16,137
# 8   2015     76,488  2,086 hrs      76,279       359 hrs      21,333   12,380
# 9   2016     87,204  2,091 hrs      88,879       372 hrs      25,151   14,410
# 10  2017     89,108  2,051 hrs      97,815       431 hrs      35,040   13,587
# ...

# %% [markdown]
# ## Welington Feliz
# #### 3 substantiated/charged, 1 unsubstantiated charge(s) in 2011<br><br>1 unsubstantiated charge in 2012

# %%
display(feliz)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2000     57,843  1,920 hrs      51,862       546 hrs      18,879    6,661
# 1   2001     68,425  2,080 hrs      60,481       714 hrs      23,962    7,596
# 2   2002     72,027  2,080 hrs      69,901       738 hrs      26,274   13,732
# 3   2003     77,392  2,080 hrs      73,922       115 hrs       5,713    9,468
# 4   2004     87,700  2,080 hrs      73,287       266 hrs      12,879    9,594
# 5   2005     87,700  2,080 hrs      79,063       300 hrs      13,747   10,402
# 6   2006     90,331  2,086 hrs      82,380       305 hrs      19,321   11,965
# 7   2007     96,229  2,086 hrs     115,181       111 hrs      13,076   12,674
# 8   2008    100,078  2,091 hrs      95,676       111 hrs       8,756   11,614
# 9   2009    104,081  2,086 hrs     108,312        86 hrs       8,230   12,851
# 10  2010    108,244  2,086 hrs     106,430       139 hrs      11,193   13,447
# ...

# %% [markdown]
# ## Benjamin Gottlieb
# #### 1 substantiated charge in 2011

# %%
display(gottlieb)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2000     33,314  1,920 hrs      30,526       321 hrs       4,615    4,677
# 1   2001     36,706  2,080 hrs      34,800       297 hrs       4,776    5,039
# 2   2002     40,441  2,080 hrs      36,514       377 hrs       5,856    5,251
# 3   2003     45,263  2,080 hrs      47,827       247 hrs       4,894    6,324
# 4   2004     59,588  2,080 hrs      53,280       164 hrs       4,405   10,752
# 5   2005     62,269  2,080 hrs      53,893       537 hrs      20,594    7,982
# 6   2006     65,382  2,086 hrs      74,234       364 hrs      21,824    9,599
# 7   2007     70,909  2,086 hrs      60,183       239 hrs      11,127    4,215
# 8   2008     73,913  2,091 hrs      69,468        20 hrs         238   14,257
# 9   2009     74,100  2,086 hrs      85,234         0 hrs       4,499   17,314
# 10  2010     78,198  2,086 hrs      82,477         3 hrs         352   16,484
# ...

# %% [markdown]
# ## Barry Stokes
# #### 1 substantiated charge in 2012

# %%
display(stokes)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2008     37,316     31 hrs         651         0 hrs           0       30
# 1   2009     40,361  2,046 hrs      38,598       138 hrs       4,065    2,273
# 2   2010     41,975  2,086 hrs      41,679       173 hrs       5,709    5,127
# 3   2011     43,644  2,086 hrs      43,747       191 hrs       6,414    5,992
# 4   2012     48,779  2,091 hrs      47,945       246 hrs       9,313    7,020
# 5   2013     53,270  2,086 hrs      52,860       276 hrs      11,451    7,424
# 6   2014     56,609  2,086 hrs      56,253       169 hrs       8,350   13,149
# 7   2015     76,488  2,086 hrs      75,026       252 hrs      13,122   15,301
# 8   2016     78,026  2,091 hrs     100,034       243 hrs      21,704   17,259
# 9   2017     85,292  2,051 hrs      96,819       163 hrs      13,707   19,532
# 10  2018     85,292  2,046 hrs      85,058        85 hrs       7,119   17,731

# %% [markdown]
# ## Freddy Tavares
# #### 2 substantiated/charged, 1 exonerated, 1 unsubstantiated charge(s) in 2012

# %%
display(tavares)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2007     37,316    909 hrs      10,453        55 hrs       1,011        0
# 1   2008     38,809  2,091 hrs      31,920        53 hrs       1,132    5,251
# 2   2009     41,965  2,086 hrs      53,150       127 hrs       5,831    7,330
# 3   2010     48,779  2,086 hrs      48,002       110 hrs       4,490    6,817
# 4   2011     53,270  2,086 hrs      52,718        90 hrs       3,073    7,283
# 5   2012     56,609  2,091 hrs      55,994       129 hrs       6,090    9,852
# 6   2013     76,488  2,086 hrs      74,312       150 hrs       9,872   14,660
# 7   2014     76,488  2,086 hrs      76,279       132 hrs       5,814   12,204
# 8   2015     76,488  2,086 hrs      76,279       211 hrs      13,323   10,588
# 9   2016     78,026  2,091 hrs      83,703       163 hrs      11,313   11,604
# 10  2017     85,292  2,051 hrs      97,216       159 hrs      12,615   13,225
# ...

# %% [markdown]
# ## John Andryuk
# #### 1 unsubstantiated charge in 2013

# %%
display(andryuk)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2003     38,722  1,994 hrs      35,067        53 hrs         880    2,288
# 1   2004     42,648  2,080 hrs      38,397       172 hrs       2,783    5,855
# 2   2005     46,132  2,080 hrs      39,859       189 hrs       3,815    4,292
# 3   2006     50,737  2,086 hrs      57,148       112 hrs       5,049    5,069
# 4   2007     54,234  2,086 hrs      47,375       162 hrs       5,741    4,480
# 5   2008     70,717  2,091 hrs      59,034       366 hrs      15,867    9,565
# 6   2009     73,745  2,086 hrs      95,853        89 hrs      10,348   14,489
# 7   2010     76,908  2,086 hrs      76,930       280 hrs      17,091   13,262
# 8   2011     80,147  2,086 hrs      79,542       355 hrs      23,757   16,417
# 9   2012     81,326  2,091 hrs      80,660       178 hrs      12,728   16,478
# 10  2013     98,072  2,086 hrs      94,446       147 hrs      10,977    8,476
# ...

# %% [markdown]
# ## Eleodoro Mata
# #### 1 unsubstantiated charge in 2013 <br><br>1 unsubstantiated charge in 2014

# %%
display(mata)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2001     32,870  1,491 hrs      22,385         4 hrs          94    1,368
# 1   2002     36,729  2,080 hrs      32,650     1,026 hrs      13,426    5,134
# 2   2003     42,043  2,080 hrs      43,563       743 hrs      13,061    6,021
# 3   2004     46,240  2,080 hrs      41,166     1,024 hrs      18,082    5,943
# 4   2005     49,665  2,080 hrs      42,639       807 hrs      15,289    6,157
# 5   2006     65,382  2,086 hrs      68,161       463 hrs      25,997   11,939
# 6   2007     67,997  2,086 hrs      59,425       595 hrs      26,908   11,843
# 7   2008     70,717  2,091 hrs      59,265       568 hrs      27,939   11,168
# 8   2009     73,546  2,086 hrs      99,083         0 hrs      11,105   16,959
# 9   2010     76,488  1,914 hrs      69,662        22 hrs           0   13,118
# 10  2011     76,488  2,086 hrs      76,279       377 hrs      24,405   16,424
# ...

# %% [markdown]
# ## Edson Brutus
# #### 2 exonerated, 1 unsubstantiated, 1 disciplined charge(s) in 2014

# %%
display(brutus)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2002          9     11 hrs          98         0 hrs           0        0
# 1   2003          9    -11 hrs          98         0 hrs           0        0
# 2   2004     40,658  1,989 hrs      35,064       146 hrs       2,221    3,035
# 3   2005     44,567  2,080 hrs      38,483       287 hrs       5,019    5,577
# 4   2006     48,439  2,086 hrs      53,014        98 hrs       4,301    6,601
# 5   2007     52,766  2,086 hrs      46,079        83 hrs       2,688    6,506
# 6   2008     56,403  2,091 hrs      47,244       224 hrs       9,319    6,709
# 7   2009     73,546  2,086 hrs      93,361       149 hrs      12,540   16,128
# 8   2010     76,488  2,086 hrs      75,948       197 hrs      12,429   14,835
# 9   2011     76,488  2,086 hrs      76,279       429 hrs      27,212   13,146
# 10  2012     76,488  2,091 hrs      76,077       569 hrs      33,644   11,476
# ...

# %% [markdown]
# ## Christopher Torturo
# #### 1 disciplined charge in 2018

# %%
display(torturo)
# Out:
#     Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0   2008     38,809  2,046 hrs      27,360       101 hrs       2,204    3,063
# 1   2009     41,965  2,086 hrs      50,346        93 hrs       3,534    3,595
# 2   2010     48,779  2,086 hrs      45,615        87 hrs       2,951    2,820
# 3   2011     53,270  2,086 hrs      50,626        90 hrs       3,171    3,083
# 4   2012     56,609  2,091 hrs      54,443       146 hrs       5,884    3,275
# 5   2013     76,488  2,086 hrs      65,053       142 hrs       7,086    7,744
# 6   2014     76,488  2,086 hrs      76,279        94 hrs       6,216   10,062
# 7   2015     76,488  2,086 hrs      76,279       174 hrs       8,736   10,817
# 8   2016     78,026  1,920 hrs      77,071        88 hrs       5,895   10,594
# 9   2017     85,292  2,051 hrs      96,734       112 hrs      10,586   14,496
# 10  2018     85,292  2,046 hrs      85,058       103 hrs       8,650   11,405

# %% [markdown]
# ## Mary-Danielle Sessoms-Swinea
# #### 2 charges (1 disciplined) in 2019

# %%
display(sessomsswinea)
# Out:
#    Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0  2017     46,805  1,915 hrs      48,279         3 hrs         107        9
# 1  2018     46,805  2,046 hrs      46,677       179 hrs       6,672    6,365

# %% [markdown]
# ## Alula Haile Selassie
# #### 1 exonerated, 1 disciplined charge(s) in 2019

# %%
display(selassie)
# Out:
#    Year baseSalary   regHours regGrossPay overtimeHours overtimePay otherPay
# 0  2013     41,975    966 hrs      18,170         0 hrs           0        0
# 1  2014     41,975  2,086 hrs      41,860       175 hrs       5,161    4,139
# 2  2015     43,644  2,086 hrs      43,415       108 hrs       3,769    6,904
# 3  2016     49,760  2,091 hrs      51,215       187 hrs       7,594    7,482
# 4  2017     59,401  2,051 hrs      66,235       251 hrs      13,384    8,513
# 5  2018     63,125  2,046 hrs      62,809       189 hrs      10,934   11,603

# %%
#html reader
htmlList = ["yuseffhamm","kierancreighton","rolandocarbonell","wilbertrodriguez","rafaeliturralde","michaelscoloveno","marcyvelez","robertcattani","ronniemorales","welingtonfeliz","benjamingottlieb","barrystokes","freddytavares","johnandryuk","eleodoromata","edsonbrutus","christophertorturo","marydaniellesessomsswinea","alulahaileselassie"]
iL = [];
stringList = []
for z in htmlList:
    with open(r'html/'+z+r'.html','r') as f:
        stringList.append(f.read())

# %%
#make individual tables
import pandas as pd
import re
iL=[]
fy=re.compile("""Year <\/span>FY(.*?)<\/div>""")
sal=re.compile("""Salary <\/span>(.*?)<\/div>""")
regHrs=re.compile("""Regular Hours <\/span>(.*?)<\/div>""")
grossPay=re.compile("""Gross Pay <\/span>(.*?)<\/div>""")
othrPay=re.compile("""Other Pay <\/span>(.*?)<\/div>""")
otPay=re.compile("""Overtime <\/span>(.*?)<\/div>""")
otHrs=re.compile("""Overtime Hours <\/span>(.*?)<\/div>""")
regexList = [fy, sal, regHrs, grossPay, otHrs, otPay, othrPay ]
for y in (stringList):
    arr=[]
    for x in regexList:
        tmpList=x.findall(y)
        tmpList.reverse()
        arr.append(tmpList)
    df = pd.DataFrame(arr, ['Year','baseSalary','regHours','regGrossPay','overtimeHours','overtimePay','otherPay'])
    iL.append(df.transpose())
hamm=iL[0];creighton=iL[1];rodriguez=iL[2];carbonell=iL[3];iturralde=iL[4];scoloveno=iL[5];velez=iL[6];cattani=iL[7];morales=iL[8];feliz=iL[9];gottlieb=iL[10];stokes=iL[11];tavares=iL[12];andryuk=iL[13];mata=iL[14];brutus=iL[15];torturo=iL[16];sessomsswinea=iL[17];selassie=iL[18];

# %%
#make overall table
firstNames = ['YUSEFF', "KIERAN", "ROLANDO", "WILBERT", "RAFAEL", "MICHAEL", "MARCY", "ROBERT", "RONNIE", "WELINGTON", "BENJAMIN", "BARRY", "FREDDY", "JOHN", "ELEODORO", "EDSON", "CHRISTOPHER", "MARY-DANIELLE", "ALULA"]
lastNames = ['HAMM', "CREIGHTON", "CARBONELL", "RODRIGUEZ JR.", "ITURRALDE JR.", "SCOLOVENO", "VELEZ", "CATTANI", "MORALES", "FELIZ", "GOTTLIEB", "STOKES", "TAVARES", "ANDRYUK", "MATA", "BRUTUS", "TORTURO", "SESSOMS-SWINEA", "HAILE SELASSIE"]
avgList=[[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[]]
for y in range(len(stringList)):
    avgList[y].append(lastNames[y])
    avgList[y].append(firstNames[y])
    for x in (range(len(regexList)-1)):
        brr = regexList[x+1].findall(stringList[y])
        tempnum=0
        for z in range(len(brr)):
            if(brr[z][-3:]=="hrs"):
                tempnum+=int(brr[z][:-4].replace(",",""))
            else:
                tempnum+=int(brr[z].replace(",",""))
        avgList[y].append(tempnum/len(brr))
copSalaries2 = pd.DataFrame(data=avgList,columns=['Last Name','First Name','averageBaseSalary','averageRegularHours','averageRegularGrossPay','averageOvertimeHours','averageOvertimePay','averageOtherPay'])
#display(copSalaries2)

# %%
#matplotlib time
import matplotlib.pyplot as plt
import numpy as np
offNames=[gottlieb,tavares,scoloveno,morales,cattani]

# %%
dataL=[]
indexL=[]
xticksL=[]
for x in range(len(gottlieb.regGrossPay)):
    dataL.append(int(gottlieb.regGrossPay[x].replace(',','')))
    indexL.append(int(gottlieb.Year[x]))
for y in range(len(gottlieb.regGrossPay)):
    if(y%2==0):
        xticksL.append(int(gottlieb.Year[y]))
print("Gottlieb")
tempDF=pd.DataFrame(data=dataL,index=indexL,columns=['Gross Pay'])
tempDF.plot(xticks=xticksL)
plt.savefig(r'figures/gottlieb.pdf', bbox_inches='tight')
# Out:
# Gottlieb

# %%
dataL=[]
indexL=[]
xticksL=[]
for x in range(len(tavares.regGrossPay)):
    dataL.append(int(tavares.regGrossPay[x].replace(',','')))
    indexL.append(int(tavares.Year[x]))
for y in range(len(tavares.regGrossPay)):
    if(y%2==0):
        xticksL.append(int(tavares.Year[y]))
print("Tavares")
tempDF=pd.DataFrame(data=dataL,index=indexL,columns=['Gross Pay'])
tempDF.plot(xticks=xticksL)
plt.savefig(r'figures/tavares.pdf', bbox_inches='tight')
# Out:
# Tavares

# %%
dataL=[]
indexL=[]
xticksL=[]
for x in range(len(scoloveno.regGrossPay)):
    dataL.append(int(scoloveno.regGrossPay[x].replace(',','')))
    indexL.append(int(scoloveno.Year[x]))
for y in range(len(scoloveno.regGrossPay)):
    if(y%2==0):
        xticksL.append(int(scoloveno.Year[y]))
print("Scoloveno")
tempDF=pd.DataFrame(data=dataL,index=indexL,columns=['Gross Pay'])
tempDF.plot(xticks=xticksL)
plt.savefig(r'figures/scoloveno.pdf', bbox_inches='tight')
# Out:
# Scoloveno

# %%
dataL=[]
indexL=[]
xticksL=[]
for x in range(len(morales.regGrossPay)):
    dataL.append(int(morales.regGrossPay[x].replace(',','')))
    indexL.append(int(morales.Year[x]))
for y in range(len(morales.regGrossPay)):
    if(y%2==0):
        xticksL.append(int(morales.Year[y]))
print("Morales")
tempDF=pd.DataFrame(data=dataL,index=indexL,columns=['Gross Pay'])
tempDF.plot(xticks=xticksL)
plt.savefig(r'figures/morales.pdf', bbox_inches='tight')
# Out:
# Morales

# %%
dataL=[]
indexL=[]
xticksL=[]
for x in range(len(cattani.regGrossPay)):
    dataL.append(int(cattani.regGrossPay[x].replace(',','')))
    indexL.append(int(cattani.Year[x]))
for y in range(len(cattani.regGrossPay)):
    if(y%2==0):
        xticksL.append(int(cattani.Year[y]))
print("Cattani")
tempDF=pd.DataFrame(data=dataL,index=indexL,columns=['Gross Pay'])
tempDF.plot(xticks=xticksL)
plt.savefig(r'figures/cattani.pdf', bbox_inches='tight')
# Out:
# Cattani

# %%
dflist = pd.read_html('html/propublica26th.html')
lst=[dflist]                     
df = pd.DataFrame(dflist[0])
#display(dflist[0])

# %%
fig, ax =plt.subplots(figsize=(12,4))
ax.axis('tight')
ax.axis('off')
the_table = ax.table(cellText=df.values,colWidths=[(1.0/7.0),(5.0/56.0),(2.0/7.0),(1.0/7.0),(1.0/7.0),(1.0/7.0),(3.0/56.0)],colLabels=df.columns,loc='center',fontsize=12)
the_table.auto_set_font_size(value=False)
the_table.set_fontsize(12)
the_table.scale(3, 3)
plt.plot()
plt.savefig(r'figures/table.pdf', bbox_inches='tight')
